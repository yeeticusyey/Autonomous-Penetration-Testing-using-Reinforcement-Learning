# %%
from bs4 import BeautifulSoup
import re
with open('nmapScan.xml', 'r') as f:
    data = f.read()
Bs_data = BeautifulSoup(data, "xml")
b_port = Bs_data.find_all('port')
hosts = Bs_data.find_all('host')
print(hosts)
len(hosts)
# Out:
# [<host endtime="1641970641" starttime="1641970430"><status reason="user-set" reason_ttl="0" state="up"/>
# <address addr="192.168.242.128" addrtype="ipv4"/>
# <hostnames>
# </hostnames>
# <ports><extraports count="989" state="closed">
# <extrareasons count="989" reason="conn-refused"/>
# </extraports>
# <port portid="135" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="139" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="netbios-ssn" ostype="Windows" product="Microsoft Windows netbios-ssn"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="445" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" extrainfo="workgroup: SMW" hostname="DFS1" method="probed" name="microsoft-ds" ostype="Windows" product="Windows Server 2012 R2 Standard 9600 microsoft-ds"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="49152" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="49153" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="49154" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="49155" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="49156" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="49159" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="49160" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="49161" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# </ports>
# <hostscript><script id="clock-skew" output="mean: -2h40m00s, deviation: 4h37m07s, median: 0s"><elem key="count">3</elem>
# <elem key="median">0</elem>
# <elem key="mean">-9600</elem>
# <elem key="stddev">16627</elem>
# </script><script id="nbstat" output="NetBIOS name: DFS1, NetBIOS user: &lt;unknown&gt;, NetBIOS MAC: 00:0c:29:a4:1b:9e (VMware)"/><script id="smb-os-discovery" output="
#   OS: Windows Server 2012 R2 Standard 9600 (Windows Server 2012 R2 Standard 6.3)
#   OS CPE: cpe:/o:microsoft:windows_server_2012::-
#   Computer name: dfs1
#   NetBIOS computer name: DFS1\x00
#   Domain name: smw.soc.com
#   Forest name: smw.soc.com
#   FQDN: dfs1.smw.soc.com
#   System time: 2022-01-12T14:56:40+08:00
# "><elem key="os">Windows Server 2012 R2 Standard 9600</elem>
# <elem key="lanmanager">Windows Server 2012 R2 Standard 6.3</elem>
# <elem key="server">DFS1\x00</elem>
# <elem key="date">2022-01-12T14:56:40+08:00</elem>
# <elem key="fqdn">dfs1.smw.soc.com</elem>
# <elem key="domain_dns">smw.soc.com</elem>
# <elem key="forest_dns">smw.soc.com</elem>
# <elem key="workgroup">SMW\x00</elem>
# <elem key="cpe">cpe:/o:microsoft:windows_server_2012::-</elem>
# </script><script id="smb-security-mode" output="
#   account_used: guest
#   authentication_level: user
#   challenge_response: supported
#   message_signing: disabled (dangerous, but default)"><elem key="account_used">guest</elem>
# <elem key="authentication_level">user</elem>
# <elem key="challenge_response">supported</elem>
# <elem key="message_signing">disabled</elem>
# </script><script id="smb2-security-mode" output="
#   2.02:
#     Message signing enabled but not required"><table key="2.02">
# <elem>Message signing enabled but not required</elem>
# </table>
# </script><script id="smb2-time" output="
#   date: 2022-01-12T06:56:40
#   start_date: 2022-01-12T06:36:02"><elem key="date">2022-01-12T06:56:40</elem>
# <elem key="start_date">2022-01-12T06:36:02</elem>
# </script></hostscript><times rttvar="49" srtt="265" to="100000"/>
# </host>, <host endtime="1641970641" starttime="1641970430"><status reason="user-set" reason_ttl="0" state="up"/>
# <address addr="192.168.242.129" addrtype="ipv4"/>
# <hostnames>
# </hostnames>
# <ports><extraports count="1000" state="filtered">
# <extrareasons count="997" reason="no-responses"/>
# <extrareasons count="3" reason="host-unreaches"/>
# </extraports>
# </ports>
# <times rttvar="32330" srtt="57055" to="186375"/>
# </host>, <host endtime="1641970641" starttime="1641970430"><status reason="user-set" reason_ttl="0" state="up"/>
# <address addr="192.168.242.130" addrtype="ipv4"/>
# <hostnames>
# </hostnames>
# <ports><extraports count="988" state="filtered">
# <extrareasons count="988" reason="no-responses"/>
# </extraports>
# <port portid="53" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="3" method="table" name="domain"/></port>
# <port portid="88" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" extrainfo="server time: 2022-01-12 06:54:24Z" method="probed" name="kerberos-sec" ostype="Windows" product="Microsoft Windows Kerberos"><cpe>cpe:/a:microsoft:kerberos</cpe><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="135" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="139" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="netbios-ssn" ostype="Windows" product="Microsoft Windows netbios-ssn"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="389" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" extrainfo="Domain: smw.soc.com, Site: Default-First-Site-Name" hostname="WIN10SERVER" method="probed" name="ldap" ostype="Windows" product="Microsoft Windows Active Directory LDAP"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="445" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" extrainfo="workgroup: SMW" hostname="WIN10SERVER" method="probed" name="microsoft-ds" ostype="Windows" product="Windows Server 2016 Standard 14393 microsoft-ds"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="464" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="3" method="table" name="kpasswd5"/></port>
# <port portid="593" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="ncacn_http" ostype="Windows" product="Microsoft Windows RPC over HTTP" version="1.0"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="636" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="8" method="probed" name="tcpwrapped"/></port>
# <port portid="3268" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" extrainfo="Domain: smw.soc.com, Site: Default-First-Site-Name" hostname="WIN10SERVER" method="probed" name="ldap" ostype="Windows" product="Microsoft Windows Active Directory LDAP"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="3269" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="8" method="probed" name="tcpwrapped"/></port>
# <port portid="57294" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# </ports>
# <hostscript><script id="clock-skew" output="mean: -2h40m00s, deviation: 4h37m07s, median: 0s"><elem key="count">3</elem>
# <elem key="median">0</elem>
# <elem key="mean">-9600</elem>
# <elem key="stddev">16627</elem>
# </script><script id="nbstat" output="NetBIOS name: WIN10SERVER, NetBIOS user: &lt;unknown&gt;, NetBIOS MAC: 00:0c:29:84:9b:21 (VMware)"/><script id="smb-os-discovery" output="
#   OS: Windows Server 2016 Standard 14393 (Windows Server 2016 Standard 6.3)
#   Computer name: win10server
#   NetBIOS computer name: WIN10SERVER\x00
#   Domain name: smw.soc.com
#   Forest name: smw.soc.com
#   FQDN: win10server.smw.soc.com
#   System time: 2022-01-12T14:56:40+08:00
# "><elem key="os">Windows Server 2016 Standard 14393</elem>
# <elem key="lanmanager">Windows Server 2016 Standard 6.3</elem>
# <elem key="server">WIN10SERVER\x00</elem>
# <elem key="date">2022-01-12T14:56:40+08:00</elem>
# <elem key="fqdn">win10server.smw.soc.com</elem>
# <elem key="domain_dns">smw.soc.com</elem>
# <elem key="forest_dns">smw.soc.com</elem>
# <elem key="workgroup">SMW\x00</elem>
# </script><script id="smb-security-mode" output="
#   account_used: guest
#   authentication_level: user
#   challenge_response: supported
#   message_signing: required"><elem key="account_used">guest</elem>
# <elem key="authentication_level">user</elem>
# <elem key="challenge_response">supported</elem>
# <elem key="message_signing">required</elem>
# </script><script id="smb2-security-mode" output="
#   2.02:
#     Message signing enabled and required"><table key="2.02">
# <elem>Message signing enabled and required</elem>
# </table>
# </script><script id="smb2-time" output="
#   date: 2022-01-12T06:56:40
#   start_date: 2022-01-12T06:35:54"><elem key="date">2022-01-12T06:56:40</elem>
# <elem key="start_date">2022-01-12T06:35:54</elem>
# </script></hostscript><times rttvar="33" srtt="279" to="100000"/>
# </host>, <host endtime="1641970641" starttime="1641970430"><status reason="user-set" reason_ttl="0" state="up"/>
# <address addr="192.168.242.131" addrtype="ipv4"/>
# <hostnames>
# </hostnames>
# <ports><extraports count="1000" state="filtered">
# <extrareasons count="997" reason="no-responses"/>
# <extrareasons count="3" reason="host-unreaches"/>
# </extraports>
# </ports>
# <times rttvar="33066" srtt="51044" to="183308"/>
# </host>, <host endtime="1641970641" starttime="1641970430"><status reason="user-set" reason_ttl="0" state="up"/>
# <address addr="192.168.242.132" addrtype="ipv4"/>
# <hostnames>
# </hostnames>
# <ports><extraports count="995" state="filtered">
# <extrareasons count="995" reason="no-responses"/>
# </extraports>
# <port portid="135" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="139" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="netbios-ssn" ostype="Windows" product="Microsoft Windows netbios-ssn"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="445" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" extrainfo="workgroup: SMW" hostname="DFS2" method="probed" name="microsoft-ds" ostype="Windows" product="Windows Server 2012 R2 Standard 9600 microsoft-ds"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="49154" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# <port portid="49156" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>
# </ports>
# <hostscript><script id="clock-skew" output="mean: -2h40m00s, deviation: 4h37m07s, median: -1s"><elem key="count">3</elem>
# <elem key="median">-1</elem>
# <elem key="mean">-9600</elem>
# <elem key="stddev">16627</elem>
# </script><script id="nbstat" output="NetBIOS name: DFS2, NetBIOS user: &lt;unknown&gt;, NetBIOS MAC: 00:0c:29:a2:52:18 (VMware)"/><script id="smb-os-discovery" output="
#   OS: Windows Server 2012 R2 Standard 9600 (Windows Server 2012 R2 Standard 6.3)
#   OS CPE: cpe:/o:microsoft:windows_server_2012::-
#   Computer name: dfs2
#   NetBIOS computer name: DFS2\x00
#   Domain name: smw.soc.com
#   Forest name: smw.soc.com
#   FQDN: dfs2.smw.soc.com
#   System time: 2022-01-12T14:56:40+08:00
# "><elem key="os">Windows Server 2012 R2 Standard 9600</elem>
# <elem key="lanmanager">Windows Server 2012 R2 Standard 6.3</elem>
# <elem key="server">DFS2\x00</elem>
# <elem key="date">2022-01-12T14:56:40+08:00</elem>
# <elem key="fqdn">dfs2.smw.soc.com</elem>
# <elem key="domain_dns">smw.soc.com</elem>
# <elem key="forest_dns">smw.soc.com</elem>
# <elem key="workgroup">SMW\x00</elem>
# <elem key="cpe">cpe:/o:microsoft:windows_server_2012::-</elem>
# </script><script id="smb-security-mode" output="
#   account_used: guest
#   authentication_level: user
#   challenge_response: supported
#   message_signing: disabled (dangerous, but default)"><elem key="account_used">guest</elem>
# <elem key="authentication_level">user</elem>
# <elem key="challenge_response">supported</elem>
# <elem key="message_signing">disabled</elem>
# </script><script id="smb2-security-mode" output="
#   2.02:
#     Message signing enabled but not required"><table key="2.02">
# <elem>Message signing enabled but not required</elem>
# </table>
# </script><script id="smb2-time" output="
#   date: 2022-01-12T06:56:40
#   start_date: 2022-01-12T06:43:04"><elem key="date">2022-01-12T06:56:40</elem>
# <elem key="start_date">2022-01-12T06:43:04</elem>
# </script></hostscript><times rttvar="56" srtt="295" to="100000"/>
# </host>]
# 5

# %%
#port, name protocol, state
hosts
for ports in b_port:
    print(ports['portid'],ports.state['state'],ports.service['name'])
# Out:
# 135 open msrpc
# 139 open netbios-ssn
# 445 open microsoft-ds
# 49152 open msrpc
# 49153 open msrpc
# 49154 open msrpc
# 49155 open msrpc
# 49156 open msrpc
# 49159 open msrpc
# 49160 open msrpc
# 49161 open msrpc
# 53 open domain
# 88 open kerberos-sec
# 135 open msrpc
# 139 open netbios-ssn
# 389 open ldap
# 445 open microsoft-ds
# 464 open kpasswd5
# 593 open ncacn_http
# 636 open tcpwrapped
# 3268 open ldap
# 3269 open tcpwrapped
# 57294 open msrpc
# 135 open msrpc
# 139 open netbios-ssn
# 445 open microsoft-ds
# 49154 open msrpc
# 49156 open msrpc

# %%
for ports in b_port:
    print(ports)
    break
# Out:
# <port portid="135" protocol="tcp"><state reason="syn-ack" reason_ttl="0" state="open"/><service conf="10" method="probed" name="msrpc" ostype="Windows" product="Microsoft Windows RPC"><cpe>cpe:/o:microsoft:windows</cpe></service></port>

# %%
allinformation= []
for host in hosts:
    list = []
    hostname = host.hostscript
    x = str(hostname).partition("OS:")[2].partition(')')[0] + ')'
    ip = host.address['addr']
    if x == ')':
        print('not found')
        continue
    ports = host.find_all('port')
    temp = []
    for port in ports:  
        temp_port = [port['portid'],port.state['state'],port.service['name']]
        temp.append(temp_port)
        
    list = [x, ip, temp]
    allinformation.append(list)
output = []
for data in allinformation:
    count= []
    for firewall in data[2]:
        if firewall[1] == 'open':
            rule = firewall[2] +', ' + firewall[0] + ', RulePermission.ALLOW'
            count.append(rule)
        else:
            continue
    output.append([data[1], count])
print(output)
# Out:
# not found
# not found
# [['192.168.242.128', ['msrpc, 135, RulePermission.ALLOW', 'netbios-ssn, 139, RulePermission.ALLOW', 'microsoft-ds, 445, RulePermission.ALLOW', 'msrpc, 49152, RulePermission.ALLOW', 'msrpc, 49153, RulePermission.ALLOW', 'msrpc, 49154, RulePermission.ALLOW', 'msrpc, 49155, RulePermission.ALLOW', 'msrpc, 49156, RulePermission.ALLOW', 'msrpc, 49159, RulePermission.ALLOW', 'msrpc, 49160, RulePermission.ALLOW', 'msrpc, 49161, RulePermission.ALLOW']], ['192.168.242.130', ['domain, 53, RulePermission.ALLOW', 'kerberos-sec, 88, RulePermission.ALLOW', 'msrpc, 135, RulePermission.ALLOW', 'netbios-ssn, 139, RulePermission.ALLOW', 'ldap, 389, RulePermission.ALLOW', 'microsoft-ds, 445, RulePermission.ALLOW', 'kpasswd5, 464, RulePermission.ALLOW', 'ncacn_http, 593, RulePermission.ALLOW', 'tcpwrapped, 636, RulePermission.ALLOW', 'ldap, 3268, RulePermission.ALLOW', 'tcpwrapped, 3269, RulePermission.ALLOW', 'msrpc, 57294, RulePermission.ALLOW']], ['192.168.242.132', ['msrpc, 135, RulePermission.ALLOW', 'netbios-ssn, 139, RulePermission.ALLOW', 'microsoft-ds, 445, RulePermission.ALLOW', 'msrpc, 49154, RulePermission.ALLOW', 'msrpc, 49156, RulePermission.ALLOW']]]
